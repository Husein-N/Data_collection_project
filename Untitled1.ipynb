# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

page = requests.get(url, headers=headers)

soup = BeautifulSoup(page.text, "html.parser")

# %%
table = soup.find("table", {"class": "wikitable sortable"})

# %%
headers = [th.text.strip() for th in table.find_all("th")]

# %%
rows = []
for tr in table.find_all("tr")[1:]:
    tds = tr.find_all("td")
    if len(tds) == len(headers):
        rows.append([td.text.strip() for td in tds])

# %%
df = pd.DataFrame(rows, columns=headers)

# %%
len(df)
# Out:
# 100

# %%
display(df.head(20))
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3    UnitedHealth Group                      Healthcare
# 3     4                 Apple            Electronics industry
# 4     5            CVS Health                      Healthcare
# 5     6    Berkshire Hathaway                    Conglomerate
# 6     7              Alphabet  Technology and cloud computing
# 7     8            ExxonMobil              Petroleum industry
# 8     9  McKesson Corporation                          Health
# 9    10               Cencora              Pharmacy wholesale
# 10   11        JPMorgan Chase              Financial services
# 11   12                Costco                          Retail
# 12   13                 Cigna                Health insurance
# 13   14             Microsoft  Technology and cloud computing
# 14   15       Cardinal Health                      Healthcare
# 15   16   Chevron Corporation              Petroleum industry
# 16   17       Bank of America                      Financials
# 17   18        General Motors             Automotive industry
# 18   19    Ford Motor Company             Automotive industry
# 19   20       Elevance Health                      Healthcare
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 680,985           5.1%  2,100,000
# 1                 637,959          11.0%  1,556,000
# 2                 400,278           7.7%    400,000
# 3                 391,035           2.0%    164,000
# 4                 372,809           4.2%    259,500
# 5                 371,433           1.9%    392,400
# 6                 350,018          13.9%    183,323
# 7                 349,595           1.5%     60,900
# 8                 308,951          11.7%     48,000
# 9                 293,959          12.1%     44,000
# 10                278,906          16.5%    317,233
# 11                254,453           5.0%    333,000
# 12                247,121          26.6%     72,398
# 13                245,122          15.7%    228,000
# 14                226,827          10.6%     48,411
# 15                202,792           0.9%     45,298
# 16                184,992          11.9%    213,193
# 17                187,442           9.1%    162,000
# 18                184,992           5.0%    171,000
# 19                177,011           3.3%    103,679
#
#                   Headquarters
# 0        Bentonville, Arkansas
# 1          Seattle, Washington
# 2        Minnetonka, Minnesota
# 3        Cupertino, California
# 4     Woonsocket, Rhode Island
# 5              Omaha, Nebraska
# 6    Mountain View, California
# 7                Spring, Texas
# 8                Irving, Texas
# 9   Conshohocken, Pennsylvania
# 10     New York City, New York
# 11        Issaquah, Washington
# 12     Bloomfield, Connecticut
# 13         Redmond, Washington
# 14                Dublin, Ohio
# 15              Houston, Texas
# 16   Charlotte, North Carolina
# 17           Detroit, Michigan
# 18          Dearborn, Michigan
# 19       Indianapolis, Indiana
